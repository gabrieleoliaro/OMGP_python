# %%
from matplotlib.pylab import plt
from omgp import *
from omgp_load import *
from parser import *

# %%
windows = new_parse('../inputs/log_file.txt')
fig = plt.figure(figsize=(6, 4))
for c in windows[2].values():
    plt.plot(range(len(c)),c)
#plt.ylim((89, 180))
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()
